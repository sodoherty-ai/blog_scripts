# %% [markdown]
# # Analysing Conversation logs.
#
# ---
#
# This was written before the SDK was updated, so I am using requests to pull the logs.
#
# **First you must get your credentials and workspace ID**. You can get all from your workspace of your conversation.

# %%
ctx = {
    'username': 'CONVERSATION_USERNAME',
    'password': 'CONVERSATION_PASSWORD',
    'workspace_id': 'CONVERSATION_WORKSPACE_ID',
    'url': 'https://gateway.watsonplatform.net/conversation/api',
    'version': '2017-04-21'
}

# %% [markdown]
# Next lets do our initial setup to make the call.

# %%
import requests
from requests.auth import HTTPBasicAuth
import json

url = '{}/v1/workspaces/{}/logs?version={}'.format(
        ctx.get('url'), 
        ctx.get('workspace_id'), 
        ctx.get('version')
)

basic_auth = HTTPBasicAuth(ctx.get('username'), ctx.get('password'))

# %% [markdown]
# Now let's go get the logs from the conversation. It will be in JSON format.

# %%
response = requests.get(url=url, auth=basic_auth)
j = json.loads(response.text)

# %% [markdown]
# Let's have a quick look at the JSON and make sure it is well structured.

# %%
print(json.dumps(j, indent=2))
# Out:
# removed output for demo (sorry!).

# %% [markdown]
# So now we get to play with pandas! This allows us to convert the JSON into a dataframe, which we can manipulate.
#
# Before we do that, you need to be aware there are normally different kinds of analysis done on logs. Qualitative, Quantitive and Debugging. Each needs different information.
#
# **Quantitive** - These are fixed metrics, like number of users, response times, common intents, etc.
#
# **Qualitative** - This is analysing how the end user is speaking, and how the system interpreted and responded. Some examples would be where the answer returned may give the wrong impression to the end user.
#
# **Debugging** - This is really looking for coding issues with your conversation tree.
#
# For logging purposes these are the main fields. All the information you need is stored in the `j['response']` object array.
#
# | Field | Usage | Description |
# |:----|:----|:----|
# |`input.text`|Qualitative|This is what the user or the application typed in.|
# |`intents[]`|Qualitative|This tells you the primary intent for the users question. You should capture the `intent` and `confidence` into columns. If the value is `[]` then means it was irrelevant. |
# |`entities[]`|Quantitive|The entities found in relation to the call. With this and intents though, it's important to understand that the application can override these values.|
# |`output.text[]`|Qualitative|This is the response shown to the user (or application).|
# |`output.log_messages`|Debugging|Capturing this field is handy to look for coding issues within your conversation tree. SPEL errors show up here if they happen.|
# |`output.nodes_visited`|Debugging Qualitive |This can be used to see how a progression through a tree happens|
# |`context.conversation_id`|All|Use this to group users conversation together. In some solutions however, one pass calls are sometimes done mid conversation. So if you do this, you need to factor that in.|
# |`system.branch_exited`|Debugging|This tells you if your conversation left a branch and returned to `root`.|
# |`system.branch_exited_reason`|Debugging|If `branch.exited` is `true` then this will tell the why. `completed` means that the branch found a matching node, and finished. `fallback` means that it could not find a matching node, so it jumps back to `root` to find the match.|
# |`context.???`|All|You may have context variables you want to capture. You can either do these individually, or code to remove conversation objects and grab what remains|
# |`request_timestamp`|Quantitive Qualitative|When conversation received the users response.|
# |`response_timestamp`|Quantitive Qualitative|When conversation responded to the user. You can do a delta to see if there are conversation performance issues, but generally keep one of the timestamp fields for analysis.
#
# ----
#
# ## Using Pandas
# For this demo I am only using a couple of fields, but should give you an example on how to build out your own logging.

# %%
import pandas as pd

# Create dataframe.
columns = ['conversation_id', 'request TS', 'response TS', 'User Input', 'Output', 'Intent', 'Confidence', 'Exit Reason', 'Logging']

rows = []

# for object in Json Logs array.
for o in j['logs']:
    row = {}
    
    # Let's shorthand the response and system object.
    r = o['response']
    s = r['context']['system']
        
    row['conversation_id'] = r['context']['conversation_id']
    row['request TS'] = o['request_timestamp']
    row['response TS'] = o['response_timestamp']
    
    if 'text' in r['input']: row['User Input'] = r['input']['text']
    if 'text' in r['output']:row['Output'] = ' '.join(r['output']['text'])
        
    if len(r['intents']) > 0:
        row['Confidence'] = r['intents'][0]['confidence']
        row['Intent'] = r['intents'][0]['intent']

   
    if 'branch_exited_reason' in s: row['Exit Reason'] = s['branch_exited_reason']
    
    if 'log_messaging' in r['output']: row['Logging'] = r['output']['log_messaging']
    
    rows.append(row)

# Build the dataframe. 
df = pd.DataFrame(rows,columns=columns)

# cleaning up dataframe. Removing NaN and converting date fields. 
df = df.fillna('')
df['request TS'] = pd.to_datetime(df['request TS'])
df['response TS'] = pd.to_datetime(df['response TS'])

# Lastly sort by conversation ID, and then request, so that the logs become readable. 
df = df.sort_values(['conversation_id', 'request TS'], ascending=[True, True])

# %% [markdown]
# Ok, let's see how that dataframe looks.

# %%
df
# Out:
#                          conversation_id              request TS  \
# 23  011ad5d4-ecf3-4e3a-8d57-17aafb8c8a30 2017-03-22 09:22:57.398
# 24  011ad5d4-ecf3-4e3a-8d57-17aafb8c8a30 2017-03-22 09:26:14.596
# 95  011ad5d4-ecf3-4e3a-8d57-17aafb8c8a30 2017-03-22 11:07:48.484
# 96  011ad5d4-ecf3-4e3a-8d57-17aafb8c8a30 2017-03-22 11:07:58.661
# 90  011ad5d4-ecf3-4e3a-8d57-17aafb8c8a30 2017-03-22 11:14:06.559
# 25  076beabb-22cc-4e76-a4b5-dd5a87af024e 2017-03-22 09:00:46.779
# 26  076beabb-22cc-4e76-a4b5-dd5a87af024e 2017-03-22 09:00:49.776
# 28  076beabb-22cc-4e76-a4b5-dd5a87af024e 2017-03-22 09:01:00.967
# 27  076beabb-22cc-4e76-a4b5-dd5a87af024e 2017-03-22 09:01:10.701
# 55  076beabb-22cc-4e76-a4b5-dd5a87af024e 2017-03-22 09:02:05.759
# 56  076beabb-22cc-4e76-a4b5-dd5a87af024e 2017-03-22 09:02:10.686
# 57  076beabb-22cc-4e76-a4b5-dd5a87af024e 2017-03-22 09:02:33.123
# 39  1568d8de-c7b0-4a8a-bfb5-bed76dc3a288 2017-03-22 09:19:45.869
# 40  1568d8de-c7b0-4a8a-bfb5-bed76dc3a288 2017-03-22 09:19:52.414
# 87  37b6de6e-2fb7-44bd-abb7-b08a854c9057 2017-03-22 08:41:48.874
# 0   37b6de6e-2fb7-44bd-abb7-b08a854c9057 2017-03-22 08:43:19.514
# 86  3eb016ac-0540-499c-b239-101dec4acbdb 2017-03-22 08:45:28.492
# 9   4dafacec-dde1-4580-b0d7-a4ba0a014403 2017-03-22 10
# 68 2017-03-22 09:45:36.753                                          what?
# 30 2017-03-22 09:05:28.143
# 29 2017-03-22 09:05:43.147                                           sure
# 58 2017-03-22 09:05:46.518                                            yes
# 59 2017-03-22 09:06:21.899           Can you give me those details again?
#
#                                                Output  \
# 23  I am not fully trained yet, but I believe the ...
# 24  I'm not sure, but this could be the answer. Pa...
# 95  I am not sure I understood, but I think this i...
# 96  Parent information of a dog will be supplied o...
# 90  I'm not sure, but this could be the answer. Ge...
# 25               I have not been trained on that yet.
# 26               I have not been trained on that yet.
# 28  Get information about us please check our "Abo...
# 27                 All our dogs eat Brand X Dog food.
# 55               What date do you want to pick up at?
# 56  Let me just check the details with you. You wa...
# 57               I have not been trained on that yet.
# 39  Welcome to Puppies for you. Please ask me a qu...
# 40  I am not sure I understood, but I think this i...
# 87  Welcome to Puppies for you. Please ask me a qu...
# 0   Let me help you with purchasing a dog. What br...
# 86  Welcome to Puppies for you. Please ask me a qu...
# 9   Welcome to Puppies for you. Please ask me a qu...
# 6                I have not been trained on that yet.
# 7   Let me help you with purchasing a dog. What br...
# 11               What date do you want to pick up at?
# 4   I'm not sure, but this could be the answer. Le...
# 20                            What breed do you want?
# 19  To get a mudi you need to agree to a breeder c...
# 15  A breeder contract is only required if you wan...
# 16  I am not fully trained yet, but I believe the ...
# 17               Great! Do you want a dog or a puppy?
# 14  Let me just check the details with you. You wa...
# 5   This is not something I have been trained on yet.
# 89  I am not fully trained yet, but I believe the ...
# ..                                                ...
# 51  Welcome to Puppies for you. Please ask me a qu...
# 52                            What breed do you want?
# 49                            What breed do you want?
# 53                            What breed do you want?
# 22  Welcome to Puppies for you. Please ask me a qu...
# 84  Let me just check the details with you. You wa...
# 85               I have not been trained on that yet.
# 33               I have not been trained on that yet.
# 32               I have not been trained on that yet.
# 34  Get information about us please check our "Abo...
# 31               I have not been trained on that yet.
# 74  Welcome to Puppies for you. Please ask me a qu...
# 73  I am not fully trained yet, but I believe the ...
# 75  Let me help you with purchasing a dog. What br...
# 79                            What breed do you want?
# 78                            What breed do you want?
# 80                            What breed do you want?
# 60  Welcome to Puppies for you. Please ask me a qu...
# 62  Let me help you with purchasing a dog. Great, ...
# 61               I have not been trained on that yet.
# 63  I'm sorry, I didn't understand that. Can you t...
# 64  I'm not sure, but this could be the answer. Le...
# 65  Great, you want the Kai Ken breed. Do you want...
# 66               What date do you want to pick up at?
# 67  Let me just check the details with you. You wa...
# 68  I am not sure I understood, but I think this i...
# 30  Welcome to Puppies for you. Please ask me a qu...
# 29      I didn't understand. Please answer yes or no.
# 58               Great! Do you want a dog or a puppy?
# 59  Our references can be checked on the "About Us...
#
#                      Intent Confidence Exit Reason Logging
# 23  DOG_PARENTS_INFORMATION   0.476605   completed
# 24  DOG_PARENTS_INFORMATION   0.463033   completed
# 95  DOG_PARENTS_INFORMATION   0.676506   completed
# 96  DOG_PARENTS_INFORMATION   0.715889   completed
# 90      BREEDER_INFORMATION    0.34065   completed
# 25      BREEDER_INFORMATION    0.07806   completed
# 26             PURCHASE_DOG  0.0819037   completed
# 28      BREEDER_INFORMATION   0.289015   completed
# 27                 DOG_FOOD   0.315675   completed
# 55             PURCHASE_DOG     0.5795
# 56             PURCHASE_DOG  0.0810711   completed
# 57      BREEDER_INFORMATION    0.13978   completed
# 39                                       completed
# 40             PURCHASE_DOG   0.574608
# 87                                       completed
# 0              PURCHASE_DOG   0.399158
# 86                                       completed
# 9                                        completed
# 6              PURCHASE_DOG  0.0808058   completed
# 7              PURCHASE_DOG   0.989752
# 11             PURCHASE_DOG   0.343826
# 4              PURCHASE_DOG   0.351599
# 20  DOG_PARENTS_INFORMATION   0.476605
# 19      BREEDER_INFORMATION   0.102667
# 15         BREEDER_CONTRACT   0.986782   completed
# 16             PURCHASE_DOG   0.471094
# 17             PURCHASE_DOG  0.0808058
# 14             PURCHASE_DOG  0.0808058   completed
# 5                 ALLOW_VET  0.0826529   completed
# 89        DOG_SOCIALISATION   0.211466   completed
# ..                      ...        ...         ...     ...
# 51                                       completed
# 52             PURCHASE_DOG  0.0808058
# 49  DOG_PARENTS_INFORMATION   0.476605
# 53      BREEDER_INFORMATION   0.129648
# 22                                       completed
# 84         DOG_MEET_PARENTS   0.151456   completed
# 85                ALLOW_VET  0.0826529   completed
# 33             PURCHASE_DOG   0.198781   completed
# 32             PURCHASE_DOG  0.0920247   completed
# 34      BREEDER_INFORMATION   0.278825   completed
# 31      BREEDER_INFORMATION   0.190147   completed
# 74                                       completed
# 73  DOG_PARENTS_INFORMATION   0.500113   completed
# 75             PURCHASE_DOG   0.737475
# 79  DOG_PARENTS_INFORMATION   0.650442
# 78             PURCHASE_DOG   0.209827
# 80      BREEDER_INFORMATION   0.102971
# 60                                       completed
# 62             PURCHASE_DOG    0.88156
# 61         DOG_MEET_PARENTS   0.125467    fallback
# 63      BREEDER_INFORMATION   0.100922   completed
# 64             PURCHASE_DOG   0.588899
# 65             PURCHASE_DOG  0.0808058
# 66             PURCHASE_DOG   0.942419
# 67      BREEDER_INFORMATION   0.100922   completed
# 68                 DOG_FOOD   0.206446   completed
# 30                                       completed
# 29             PURCHASE_DOG  0.0808058
# 58             PURCHASE_DOG  0.0808058
# 59       BREEDER_REFERENCES   0.226893   completed
#
# [100 rows x 9 columns]

# %% [markdown]
# ## Examples of Qualitative

# %%
# This one gives you how many inputs and outputs per conversation
qualitative1 = df.groupby('conversation_id').count()
qualitative1 = qualitative1.drop(['request TS', 'response TS', 'Intent', 'Confidence', 'Exit Reason', 'Logging'], axis=1)

print('Inputs per conversation:\n    Min: {}.\n    Max: {}.\n    Mean: {}.'.format(
    qualitative1['User Input'].min(),
    qualitative1['User Input'].max(),
    qualitative1['User Input'].mean()
))
print()


# This one will count the intents and sort by decending. 
qualitative2 = df.groupby('Intent').count()
qualitative2 = qualitative2.drop(['request TS', 'response TS', 'User Input', 'Output', 'Confidence', 'Exit Reason', 'Logging'],axis=1)
qualitative2.columns = ['Count']
qualitative2 = qualitative2.sort_values(['Count'], ascending=[False])

qualitative2
# Out:
# Inputs per conversation:
#     Min: 1.
#     Max: 12.
#     Mean: 4.545454545454546.
#                           Count
# Intent
# PURCHASE_DOG                 32
# BREEDER_INFORMATION          17
#                              16
# DOG_PARENTS_INFORMATION      11
# DOG_FOOD                      6
# ALLOW_VET                     3
# DOG_SOCIALISATION             3
# BREEDER_REFERENCES            2
# DOG_HEALTH                    2
# DOG_MEET_PARENTS              2
# DOG_VACCINATIONS              2
# BREEDER_CONTRACT              1
# DOG_CERTIFICATION             1
# DOG_LIMITED_REGISTRATION      1
# LITTER_HEALTH                 1

# %% [markdown]
# ## Example of Quantitive
#
# These are really determined by reading the logs, and following Quantitive analysis steps. So this is only one example.

# %%
print('This list is an example where conversations misunderstood a question')
quantitive2 = df[df['Output'] == 'I have not been trained on that yet.']
quantitive2 = quantitive2.drop(['request TS', 'response TS', 'Output', 'Exit Reason', 'Logging'], axis=1)

quantitive2
# Out:
# This list is an example where conversations misunderstood a question
#                          conversation_id                     User Input  \
# 25  076beabb-22cc-4e76-a4b5-dd5a87af024e                       awesome!
# 26  076beabb-22cc-4e76-a4b5-dd5a87af024e                             ok
# 57  076beabb-22cc-4e76-a4b5-dd5a87af024e              See you next week
# 6   4dafacec-dde1-4580-b0d7-a4ba0a014403                            Hi
# 93  90405ca6-7083-4c90-9fb0-a4229a608652                 Ok thanks, bye
# 85  dc919e4a-0204-4811-8243-611e2ef1e489                        Thanks!
# 33  e276ee6d-bd01-4fb2-a350-48bd49f12efa  What questions can I ask you:
# 32  e276ee6d-bd01-4fb2-a350-48bd49f12efa                          Hello
# 31  e276ee6d-bd01-4fb2-a350-48bd49f12efa       How old is the business?
# 61  f5dc320f-ee2a-42ce-bf5d-593f4c98b310                   I don't know
#
#                  Intent Confidence
# 25  BREEDER_INFORMATION    0.07806
# 26         PURCHASE_DOG  0.0819037
# 57  BREEDER_INFORMATION    0.13978
# 6          PURCHASE_DOG  0.0808058
# 93            ALLOW_VET  0.0915973
# 85            ALLOW_VET  0.0826529
# 33         PURCHASE_DOG   0.198781
# 32         PURCHASE_DOG  0.0920247
# 31  BREEDER_INFORMATION   0.190147
# 61     DOG_MEET_PARENTS   0.125467

# %% [markdown]
# ## Examples of Debugging.

# %%
print('This list is where you check for possible broken branches')
debug = df[df['Exit Reason'] == 'fallback']
debug
# Out:
# This list is where you check for possible broken branches
#                          conversation_id              request TS  \
# 61  f5dc320f-ee2a-42ce-bf5d-593f4c98b310 2017-03-22 09:43:31.625
#
#                response TS    User Input  \
# 61 2017-03-22 09:43:31.654  I don't know
#
#                                   Output            Intent Confidence  \
# 61  I have not been trained on that yet.  DOG_MEET_PARENTS   0.125467
#
#    Exit Reason Logging
# 61    fallback
